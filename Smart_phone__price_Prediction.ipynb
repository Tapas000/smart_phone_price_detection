# %%
import numpy as np
import pandas as pd

import seaborn as sns

# %%
df = pd.read_csv('/content/Smart_phone_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
df['rating'].fillna(df['rating'].mean(), inplace = True)
# Out:
# <ipython-input-14-ce1e239f1147>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df['rating'].mean(), inplace = True)

# %%
df['fast_charging'].fillna(0,inplace  = True)
# Out:
# <ipython-input-15-851139970a4c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fast_charging'].fillna(0,inplace  = True)

# %%
df['rating']
# Out:
# 0      89.0
# 1      81.0
# 2      75.0
# 3      81.0
# 4      82.0
#        ...
# 975    83.0
# 976    75.0
# 977    85.0
# 978    80.0
# 979    74.0
# Name: rating, Length: 980, dtype: float64

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                  0
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    413
# helio         201
# dimensity     177
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           7
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: count, dtype: int64

# %%
df['processor_brand'].fillna('snapdragon',inplace = True)
# Out:
# <ipython-input-19-e384ef823b5e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['processor_brand'].fillna('snapdragon',inplace = True)

# %%
df['processor_speed'].fillna(df['processor_speed'].mean(),inplace = True)
# Out:
# <ipython-input-20-5bac6e5043fb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['processor_speed'].fillna(df['processor_speed'].mean(),inplace = True)

# %%
df['os'].value_counts()
# Out:
# os
# android    909
# ios         46
# other       11
# Name: count, dtype: int64

# %%
df['primary_camera_front'].value_counts()
# Out:
# primary_camera_front
# 16.0    307
# 8.0     178
# 32.0    155
# 5.0     119
# 12.0     50
# 13.0     41
# 20.0     37
# 10.0     24
# 50.0     12
# 60.0     10
# 44.0      8
# 40.0      6
# 2.0       5
# 7.0       5
# 24.0      3
# 25.0      3
# 10.8      3
# 48.0      2
# 11.1      2
# 0.3       1
# 2.1       1
# 10.7      1
# 10.1      1
# 12.6      1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     980 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            980 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            980 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              980 non-null    float64
# ...

# %%
df['num_cores'].fillna(2,inplace  = True)
df['os'].fillna('android',inplace = True)
df['battery_capacity'].fillna(df['battery_capacity'].mean(),inplace = True)
df['num_front_cameras'].fillna(1,inplace  = True)
df['primary_camera_front'].fillna(16.0,inplace = True)
# Out:
# <ipython-input-24-b7bfb6c010d4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['num_cores'].fillna(2,inplace  = True)
# <ipython-input-24-b7bfb6c010d4>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                         0
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand                0
# num_cores                      0
# processor_speed                0
# battery_capacity               0
# fast_charging_available        0
# fast_charging                  0
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              0
# os                             0
# primary_camera_rear            0
# primary_camera_front           0
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
df.drop(columns = ['extended_upto'],inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     980 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            980 non-null    object
#  8   num_cores                  980 non-null    float64
#  9   processor_speed            980 non-null    float64
#  10  battery_capacity           980 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              980 non-null    float64
# ...

# %%
df['ppi'] = (df['resolution_width']**2) +(df['resolution_height']**2)**0.5/df['screen_size']

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
df.drop(columns = ['screen_size','resolution_width','resolution_height'],inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     980 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            980 non-null    object
#  8   num_cores                  980 non-null    float64
#  9   processor_speed            980 non-null    float64
#  10  battery_capacity           980 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              980 non-null    float64
# ...

# %%
df['num_rear_cameras'].corr(df['price'])
# Out:
# 0.12533004007475723

# %%
df['ram_capacity'].corr(df['price'])
# Out:
# 0.3860016700183043

# %%
df['primary_camera_front'].corr(df['price'])
# Out:
# 0.15971991296096325

# %%
df['extended_memory_available'].corr(df['price'])# drop
# Out:
# -0.4486282266650539

# %%
df['internal_memory'].corr(df['price'])  # strong Correlation with price
# Out:
# 0.557167632826264

# %%
df['rating'].corr(df['price'])

# %%
df['battery_capacity'].corr(df['price']) # not use full
# Out:
# -0.15753193415891567

# %%
df['processor_speed'].corr(df['price'])
# Out:
# 0.44832427348376436

# %%
df['num_cores'].corr(df['price']) # not  -ve corr so it is not important it can be droped
# Out:
# -0.09564255049853994

# %%
df.drop(columns = ['rating','has_ir_blaster','num_cores','battery_capacity','fast_charging_available','fast_charging','primary_camera_rear','primary_camera_front','extended_memory_available'],inplace = True)

# %%
df.head()
# Out:
#   brand_name                      model  price  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    True    False
# 3   motorola       Motorola Moto G62 5G  14999    True    False
# 4     realme         Realme 10 Pro Plus  24999    True    False
#
#   processor_brand  processor_speed  ram_capacity  internal_memory  \
# 0      snapdragon              3.2          12.0            256.0
# 1      snapdragon              2.2           6.0            128.0
# 2          exynos              2.4           4.0             64.0
# 3      snapdragon              2.2           6.0            128.0
# 4       dimensity              2.6           6.0            128.0
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os           ppi
# 0           120                 3                1.0  android  2.074080e+06
# ...

# %%
sns.distplot(np.log(df['price']))
# Out:
# <ipython-input-67-753ce9645879>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['price']))
# <Axes: xlabel='price', ylabel='Density'>

# %%
df
# Out:
#     brand_name                            model  price  has_5g  has_nfc  \
# 0      oneplus                    OnePlus 11 5G  54999    True     True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    True    False
# 2      samsung            Samsung Galaxy A14 5G  16499    True    False
# 3     motorola             Motorola Moto G62 5G  14999    True    False
# 4       realme               Realme 10 Pro Plus  24999    True    False
# ..         ...                              ...    ...     ...      ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    True    False
# 976      honor                      Honor X8 5G  14990    True    False
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    True     True
# 978   motorola             Motorola Moto G91 5G  19990    True     True
# 979    samsung           Samsung Galaxy M52s 5G  24990    True    False
#
#     processor_brand  processor_speed  ram_capacity  internal_memory  \
# ...

# %%
df['company']=df['model'].apply(lambda x:x.split()[0])

# %%
df['company'].value_counts()
# Out:
# company
# Xiaomi       134
# Samsung      132
# Vivo         111
# Realme        97
# OPPO          62
# Motorola      52
# Apple         46
# OnePlus       42
# Tecno         33
# iQOO          32
# Infinix       29
# Poco          28
# Oppo          26
# Huawei        16
# Google        14
# Honor         13
# POCO          13
# Nokia         13
# Sony           9
# itel           8
# Asus           7
# Nubia          6
# Nothing        5
# Lava           4
# Jio            4
# Redmi          3
# Letv           3
# Micromax       3
# Oukitel        3
# Gionee         3
# iKall          3
# LG             3
# Doogee         2
# Royole         2
# Lyf            2
# Itel           2
# ZTE            2
# Lenovo         2
# TCL            1
# CAT            1
# Leitz          1
# Sharp          1
# Cola           1
# BLU            1
# Vertu          1
# Duoqin         1
# LeEco          1
# Tesla          1
# Blackview      1
# Name: count, dtype: int64

# %%
df.drop(columns = ['company','model'],inplace = True)

# %%
df['has_5g']=df['has_5g'].astype(int)
df['has_nfc']=df['has_nfc'].astype(int)

# %%
# Out:
# <Axes: xlabel='brand_name', ylabel='price'>

# %%
df['brand_name'].value_counts()
# Out:
# brand_name
# xiaomi       134
# samsung      132
# vivo         111
# realme        97
# oppo          88
# motorola      52
# apple         46
# oneplus       42
# poco          41
# tecno         33
# iqoo          32
# infinix       29
# huawei        16
# google        14
# nokia         13
# honor         13
# itel          10
# sony           9
# asus           7
# nubia          6
# nothing        5
# lava           4
# jio            4
# gionee         3
# micromax       3
# oukitel        3
# lg             3
# redmi          3
# letv           3
# ikall          3
# royole         2
# doogee         2
# zte            2
# lenovo         2
# lyf            2
# sharp          1
# tcl            1
# cat            1
# leitz          1
# duoqin         1
# leeco          1
# blu            1
# vertu          1
# tesla          1
# cola           1
# blackview      1
# Name: count, dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    432
# helio         200
# dimensity     177
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           7
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: count, dtype: int64

# %%
df   = df[(df['brand_name'] != 'vertu') & (df['brand_name'] != 'cola')& (df['processor_brand'] != 'mediatek') & (df['processor_brand'] != 'sc9863a')  ]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import  Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder, FunctionTransformer

# %%
X = df.drop(columns = ['price'])
y = y = np.log(df['price'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state= 2)

# %%
df.head(1)
# Out:
#   brand_name  price  has_5g  has_nfc processor_brand  processor_speed  \
# 0    oneplus  54999       1        1      snapdragon              3.2
#
#    ram_capacity  internal_memory  refresh_rate  num_rear_cameras  \
# 0          12.0            256.0           120                 3
#
#    num_front_cameras       os        ppi
# 0                1.0  android  2074080.0

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['brand_name','processor_brand','os'])
],remainder='passthrough')

step2 = RandomForestRegressor(
    n_estimators=200,       # Number of trees
    max_depth=10,           # Limit tree depth
    min_samples_split=5,    # Minimum samples to split a node
    min_samples_leaf=3,     # Minimum samples in a leaf node
    max_features='sqrt',    # Number of features per split
    bootstrap=True,         # Use bootstrap samples
    n_jobs=-1,              # Use all CPU cores
    random_state=42
    )

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
]).set_output(transform="pandas")

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('r2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8282090514584743
# MAE 0.18647834506559127

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['brand_name','processor_brand','os'])
],remainder='passthrough')

step2 = XGBRegressor(
    n_estimators=200,       # Number of trees
    learning_rate=0.05,     # Shrinks the impact of trees
    max_depth=4,           # Controls model complexity
    min_child_weight=3,    # Minimum weight needed in a leaf node
    gamma=0.2,             # Minimum loss reduction to make a split
    subsample=0.8,         # Uses 80% of data per boosting round
    colsample_bytree=0.8,  # Uses 80% of features per tree
    lambda_=1.0,           # L2 regularization
    alpha=0.5,             # L1 regularization
    n_jobs=-1,             # Uses all CPU cores
    random_state=42
    )

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
]).set_output(transform="pandas")

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('r2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8343592725049663
# MAE 0.18415556240091702
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:52:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "lambda_" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),['brand_name','processor_brand','os'])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8462966562885811
# MAE 0.17877160890342758

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
X_train
# Out:
#     brand_name  has_5g  has_nfc processor_brand  processor_speed  \
# 295       oppo       1        0      snapdragon         2.200000
# 152      apple       1        1          bionic         2.427217
# 814    infinix       0        0           helio         2.000000
# 259       poco       1        0       dimensity         2.200000
# 860       oppo       1        0      snapdragon         2.200000
# ..         ...     ...      ...             ...              ...
# 537     lenovo       1        1      snapdragon         3.000000
# 587     xiaomi       1        0       dimensity         2.200000
# 496     realme       0        0           tiger         1.820000
# 530       poco       0        0           helio         2.200000
# 169       letv       0        0           tiger         2.000000
#
#      ram_capacity  internal_memory  refresh_rate  num_rear_cameras  \
# 295           8.0            128.0            60                 3
# ...
