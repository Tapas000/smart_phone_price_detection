# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/laptop_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype("float32")

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-570-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x = df['Company'],y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x = df['TypeName'],y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x = df['Touchscreen'],y = df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['full_HD']=df['ScreenResolution'].apply(lambda x:1 if '1920x1080' in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['full_HD'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='full_HD'>

# %%
sns.barplot(x = df['full_HD'],y = df['Price'])
# Out:
# <Axes: xlabel='full_HD', ylabel='Price'>

# %%
df['IPS']= df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['x_res'] = new[0]
df['y_res'] = new[1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['x_res'] =df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['x_res']=df['x_res'].astype('int')
df['y_res']=df['y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  full_HD           1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  x_res             1303 non-null   int64
#  15  y_res             1303 non-null   int64
# ...

# %%
df['ppi']=((df['x_res']**2)+ (df['y_res']**2))**0.5/df['Inches']

# %%
df['ppi'].corr(df['Price'])
# Out:
# 0.4734873076608601

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.drop(columns=['Inches','ScreenResolution','x_res','y_res'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    full_HD  IPS         ppi
# 0        0    1  226.983005
# ...

# %%
df['Cpu name'] =df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    full_HD  IPS         ppi       Cpu name
# ...

# %%
def fetch_processor(text):
  if text == 'Intel Core i5' or text =='Intel Core i3' or text =='Intel Core i7':
    return text

  else:
    if text.split()[0] == 'Intel':
      return 'Other Intel Processor'

    else:
      return "AMD Processor"

# %%
df['Cpu Brand']=df['Cpu name'].apply(fetch_processor)

# %%
df.sample(5)
# Out:
#      Company            TypeName                          Cpu  Ram  \
# 982   Lenovo            Notebook  AMD A12-Series 9720P 3.6GHz    6
# 808     Dell              Gaming  Intel Core i7 7700HQ 2.8GHz   16
# 1114  Lenovo  2 in 1 Convertible  Intel Atom x5-Z8550 1.44GHz    4
# 534     Asus              Gaming  Intel Core i5 7300HQ 2.5GHz    8
# 1197    Asus              Gaming  Intel Core i7 6700HQ 2.6GHz   16
#
#                     Memory                         Gpu       OpSys  Weight  \
# 982              256GB SSD              AMD Radeon 530  Windows 10    2.20
# 808              512GB SSD  Nvidia GeForce GTX 1050 Ti  Windows 10    2.62
# 1114    64GB Flash Storage       Intel HD Graphics 400     Android    0.69
# 534   128GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10    2.30
# 1197  512GB SSD +  1TB HDD     Nvidia GeForce GTX 980M  Windows 10    4.30
#
#           Price  Touchscreen  full_HD  IPS         ppi              Cpu name  \
# ...

# %%
df['Cpu Brand'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x = df['Cpu Brand'],y = df['Price'])
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Intel Core i5'),
#   Text(1, 0, 'Intel Core i7'),
#   Text(2, 0, 'AMD Processor'),
#   Text(3, 0, 'Intel Core i3'),
#   Text(4, 0, 'Other Intel Processor')])

# %%
df.drop(columns = ['Cpu','Cpu name'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  full_HD  IPS         ppi  \
# 0  macOS    1.37   71378.6832            0        0    1  226.983005
# 1  macOS    1.34   47895.5232            0        0    0  127.677940
# 2  No OS    1.86   30636.0000            0        1    0  141.211998
# 3  macOS    1.83  135195.3360            0        0    1  220.534624
# 4  macOS    1.37   96095.8080            0        0    1  226.983005
#
#        Cpu Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# ...

# %%
df['Memory']=df['Memory'].apply(lambda x: " ".join( x.split()[0]))

# %%
df.head()
# Out:
#   Company   TypeName  Ram     Memory                           Gpu  OpSys  \
# 0   Apple  Ultrabook    8  1 2 8 G B  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    8  1 2 8 G B        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    8  2 5 6 G B         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook   16  5 1 2 G B            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    8  2 5 6 G B  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  full_HD  IPS         ppi      Cpu Brand
# 0    1.37   71378.6832            0        0    1  226.983005  Intel Core i5
# 1    1.34   47895.5232            0        0    0  127.677940  Intel Core i5
# 2    1.86   30636.0000            0        1    0  141.211998  Intel Core i5
# 3    1.83  135195.3360            0        0    1  220.534624  Intel Core i7
# 4    1.37   96095.8080            0        0    1  226.983005  Intel Core i5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Ram          1303 non-null   int32
#  3   Memory       1303 non-null   object
#  4   Gpu          1303 non-null   object
#  5   OpSys        1303 non-null   object
#  6   Weight       1303 non-null   float32
#  7   Price        1303 non-null   float64
#  8   Touchscreen  1303 non-null   int64
#  9   full_HD      1303 non-null   int64
#  10  IPS          1303 non-null   int64
#  11  ppi          1303 non-null   float64
#  12  Cpu Brand    1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(3), object(6)
# memory usage: 122.3+ KB

# %%
df['Memory']=df['Memory'].str.replace('G B','')

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Memory                           Gpu  OpSys  \
# 0   Apple  Ultrabook    8  1 2 8   Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    8  1 2 8         Intel HD Graphics 6000  macOS
# 2      HP   Notebook    8  2 5 6          Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook   16  5 1 2             AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    8  2 5 6   Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  full_HD  IPS         ppi      Cpu Brand
# 0    1.37   71378.6832            0        0    1  226.983005  Intel Core i5
# 1    1.34   47895.5232            0        0    0  127.677940  Intel Core i5
# 2    1.86   30636.0000            0        1    0  141.211998  Intel Core i5
# 3    1.83  135195.3360            0        0    1  220.534624  Intel Core i7
# 4    1.37   96095.8080            0        0    1  226.983005  Intel Core i5

# %%
df['Memory']=df['Memory'].str.replace(' ','')

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram Memory                           Gpu  \
# 683       HP            Notebook    4    256             AMD Radeon R5 520
# 399   Lenovo           Ultrabook   16    1TB         Intel HD Graphics 620
# 310   Lenovo            Notebook    8    256         Intel HD Graphics 620
# 1168      HP            Notebook    2     32         Intel HD Graphics 400
# 942     Acer            Notebook    4    500         Intel HD Graphics 620
# 4      Apple           Ultrabook    8    256  Intel Iris Plus Graphics 650
# 455     Dell  2 in 1 Convertible    4    500         Intel HD Graphics 405
# 186     Dell            Notebook   16    512       Nvidia GeForce GTX 1050
# 248       HP            Notebook    4    500        Intel UHD Graphics 620
# 1108      HP            Notebook    4    1TB                 AMD Radeon R4
#
#            OpSys  Weight       Price  Touchscreen  full_HD  IPS         ppi  \
# ...

# %%
df['Memory']=df['Memory'].str.replace('TB','024')

# %%
df['Memory']=df['Memory'].astype(float)

# %%
df['Memory']=df['Memory'].astype(int)

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256     508
# 1024    240
# 128     177
# 512     140
# 500     132
# 32       45
# 64       17
# 2024     16
# 1        10
# 16       10
# 180       5
# 240       1
# 8         1
# 508       1
# Name: count, dtype: int64

# %%
df = df[~df['Memory'].isin([1,16, 8,32,64,180,240,508])]

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256     508
# 1024    240
# 128     177
# 512     140
# 500     132
# 2024     16
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Memory                           Gpu  OpSys  \
# 0   Apple  Ultrabook    8     128  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    8     128        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    8     256         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook   16     512            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    8     256  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  full_HD  IPS         ppi      Cpu Brand
# 0    1.37   71378.6832            0        0    1  226.983005  Intel Core i5
# 1    1.34   47895.5232            0        0    0  127.677940  Intel Core i5
# 2    1.86   30636.0000            0        1    0  141.211998  Intel Core i5
# 3    1.83  135195.3360            0        0    1  220.534624  Intel Core i7
# 4    1.37   96095.8080            0        0    1  226.983005  Intel Core i5

# %%
df['Gpu brand']= df['Gpu'].apply(lambda x:x.split()[0])
# Out:
# <ipython-input-623-b3af600daa94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu brand']= df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     646
# Nvidia    396
# AMD       171
# Name: count, dtype: int64

# %%
df.drop(columns = ['Gpu'],inplace  = True)
# Out:
# <ipython-input-625-1457a104877b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['Gpu'],inplace  = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Memory  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    8     128  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    8     128  macOS    1.34   47895.5232            0
# 2      HP   Notebook    8     256  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook   16     512  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    8     256  macOS    1.37   96095.8080            0
#
#    full_HD  IPS         ppi      Cpu Brand Gpu brand
# 0        0    1  226.983005  Intel Core i5     Intel
# 1        0    0  127.677940  Intel Core i5     Intel
# 2        1    0  141.211998  Intel Core i5     Intel
# 3        0    1  220.534624  Intel Core i7       AMD
# 4        0    1  226.983005  Intel Core i5     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1014
# No OS             66
# Linux             62
# Windows 7         41
# macOS             13
# Mac OS X           8
# Windows 10 S       6
# Chrome OS          3
# Name: count, dtype: int64

# %%
def fetch_os(text):
  if text == 'Windows 10'or text == 'Windows 7'or text == 'Windows 10 S':
    return 'Windows'

  else:
    if text == 'macOS' or text == 'Mac OS X' :
      return 'Mac'
    else:
      return 'No OS/Linux/Chrome OS'

# %%
df['Operating system'] = df['OpSys'].apply(fetch_os)
# Out:
# <ipython-input-629-5c2475c1690f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Operating system'] = df['OpSys'].apply(fetch_os)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram  Memory       OpSys  Weight     Price  \
# 1194    Dell  2 in 1 Convertible    8     256  Windows 10    1.60  63882.72
# 45     Apple           Ultrabook    8     256       macOS    1.37  75604.32
# 924   Lenovo  2 in 1 Convertible    8     512  Windows 10    1.37  97236.00
# 193   Lenovo            Notebook    8     256       No OS    2.80  37189.44
# 175     Dell            Notebook    8    1024  Windows 10    2.30  24455.52
#
#       Touchscreen  full_HD  IPS         ppi      Cpu Brand Gpu brand  \
# 1194            1        1    1  165.632118  Intel Core i5     Intel
# 45              0        0    1  226.983005  Intel Core i5     Intel
# 924             1        1    1  165.632118  Intel Core i5     Intel
# 193             0        0    0  106.113062  Intel Core i5    Nvidia
# 175             0        0    0  100.454670  Intel Core i3     Intel
#
#            Operating system
# 1194                Windows
# 45                      Mac
# ...

# %%
df.drop(columns = ['OpSys'],inplace= True)
# Out:
# <ipython-input-631-407cb84b09ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['OpSys'],inplace= True)

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-632-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state= 2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import  Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %% [markdown]
# # **XGboost**

# %%
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
# ],remainder='passthrough')

# step2 = XGBRegressor()

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)
# print('r2_score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %% [markdown]
# # **DecisionTreeRegressor**

# %%
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
# ],remainder='passthrough')

# step2 = DecisionTreeRegressor()

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)
# print('r2_score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %% [markdown]
# # **RandomForestRegressor**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
],remainder='passthrough')

step2 = RandomForestRegressor()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
]).set_output(transform="pandas")

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('r2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.8848859655180993
# MAE 0.14194510250319817

# %% [markdown]
# # **GradientBoostingRegressor**

# %%
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
# ],remainder='passthrough')

# step2 = GradientBoostingRegressor()

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)
# print('r2_score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %% [markdown]
# # **AdaBoostRegressor**

# %%
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
# ],remainder='passthrough')

# step2 = AdaBoostRegressor()

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)
# print('r2_score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Memory  Weight       Price  Touchscreen  full_HD  \
# 0   Apple  Ultrabook    8     128    1.37  71378.6832            0        0
#
#    IPS         ppi      Cpu Brand Gpu brand Operating system
# 0    1  226.983005  Intel Core i5     Intel              Mac

# %% [markdown]
# # **VotingRegressor**

# %%
# from sklearn.ensemble import VotingRegressor
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
# ],remainder='passthrough')

# rf = RandomForestRegressor()
# gb = GradientBoostingRegressor()
# ad = AdaBoostRegressor()
# xg = XGBRegressor()

# step2 = VotingRegressor([('rf',rf),('gb',gb),('ad',ad),('xg',xg)],weights=[5,1,1,1])

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)
# print('r2_score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %%
# from sklearn.ensemble import StackingRegressor

# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop= 'first'), ['Company', 'TypeName', 'Gpu brand', 'Cpu Brand', 'Operating system'])
# ],remainder='passthrough')

# estimators = [
#     ('rf',RandomForestRegressor()),
#     ('xg',XGBRegressor()),
#     ('gb',GradientBoostingRegressor())
# ]

# step2 = StackingRegressor(estimators=estimators,final_estimator=Ridge(alpha = 100))

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)
# print('r2_score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %%
X_train
# Out:
#      Company   TypeName  Ram  Memory  Weight  Touchscreen  full_HD  IPS  \
# 1264    Dell   Notebook    2     500    2.20            0        0    0
# 22        HP   Notebook    4     500    1.86            0        0    0
# 1011      HP  Ultrabook    4     500    1.26            0        1    0
# 762   Google  Ultrabook    8     256    1.10            1        0    0
# 751       HP   Notebook    8     256    1.84            0        1    0
# ...      ...        ...  ...     ...     ...          ...      ...  ...
# 489     Asus  Ultrabook   16     512    0.91            0        1    0
# 309       HP   Notebook    4    1024    1.86            0        1    0
# 520   Lenovo     Gaming    8     256    3.20            0        1    1
# 555     Asus   Notebook    4     500    2.00            0        0    0
# 1276    Dell   Notebook    6    1024    2.30            0        0    0
#
#              ppi              Cpu Brand Gpu brand       Operating system
# ...

# %%
df['Ram'].unique()
# Out:
# array([ 8, 16,  4, 12,  6, 32, 24, 64,  2], dtype=int32)

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
common_resolutions = [
      "1366x768",
      "1920x1080",
      "2560x1440",
      "2560x1600",
      "2880x1800",
      "3200x1800",
      "3840x2160"
]

print(common_resolutions)
# Out:
# ['1366x768', '1920x1080', '2560x1440', '2560x1600', '2880x1800', '3200x1800', '3840x2160']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1213 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1213 non-null   object
#  1   TypeName          1213 non-null   object
#  2   Ram               1213 non-null   int32
#  3   Memory            1213 non-null   int64
#  4   Weight            1213 non-null   float32
#  5   Price             1213 non-null   float64
#  6   Touchscreen       1213 non-null   int64
#  7   full_HD           1213 non-null   int64
#  8   IPS               1213 non-null   int64
#  9   ppi               1213 non-null   float64
#  10  Cpu Brand         1213 non-null   object
#  11  Gpu brand         1213 non-null   object
#  12  Operating system  1213 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 123.2+ KB
